# %%
# %%bash
# mkdir Repository

# %%
# %%bash
# cd Repository/
# touch README.md
# ls
# Out:
# README.md

# %%
# %%bash
# cd Repository/
# mkdir summarydata
# mkdir notebook
# mkdir figure
# mkdir multipanel
# ls

# %%
# %%bash
# cd Repository/
# cd summarydata/
# touch README.md
# touch Figure_1adata.csv
# touch Figure_1bdata.csv
# touch Figure_2adata.csv
# touch Figure_2bdata.csv
# touch Figure_2cdata.csv
# ls
# Out:
# Figure_1adata.csv
# Figure_1bdata.csv
# Figure_2adata.csv
# Figure_2bdata.csv
# Figure_2cdata.csv
# README.md

# %%
# %%bash
# cd Repository/
# cd notebook/
# touch README.md
# touch Figure1.ipynb
# touch Figure2.ipynb
# ls
# Out:
# Figure1.ipynb
# Figure2.ipynb
# README.md

# %%
# %%bash
# cd Repository/
# cd figure/
# touch README.md
# touch Figure1a.pdf
# touch Figure1b.pdf
# touch Figure2a.pdf
# touch Figure2b.pdf
# touch Figure2c.pdf
# ls
# Out:
# Figure1a.pdf
# Figure1b.pdf
# Figure2a.pdf
# Figure2b.pdf
# Figure2c.pdf
# README.md

# %%
# %%bash
# cd Repository/
# cd multipanel/
# touch README.md
# touch Figure1.ai
# touch Figure2.ai
# ls
# Out:
# Figure1.ai
# Figure2.ai
# README.md
